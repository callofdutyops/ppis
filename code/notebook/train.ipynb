# %%
import pandas as pd
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np

from common import (
    delta_g_path,
    id_seq_path
)
from char_table import CharTable

# %%
# load processed files
df_delta_g = pd.read_csv(delta_g_path)
df_id_seq = pd.read_csv(id_seq_path)

MAXLEN = int(np.percentile(df_id_seq["seqs"].map(lambda x: len(x)), 90))

# %%
MAXLEN
# Out:
# 434

# %%
all_symbol_set = set()
id_seq_dict = {}
for idx, row in df_id_seq.iterrows():
    seqs = row["seqs"]
    id_seq_dict[row["id"]] = seqs
    all_symbol_set.update(seqs)

# %%
ctable = CharTable(all_symbol_set)

# %%
inputs = []
outputs = []
for idx, row in df_delta_g.iterrows():
    skip_flag = False
    for key in ["wt_name_0", "wt_name_1", "mut_name_0", "mut_name_1"]:
        seqs = id_seq_dict[row[key]]
        if len(seqs) > MAXLEN:
            skip_flag = True
            break
    if skip_flag:
        continue

    # wt
    input_item = []
    for key in ["wt_name_0", "wt_name_1"]:
        seqs = id_seq_dict[row[key]]
        delta_g = row["delta_g_wt"]
        encoded = ctable.encode(seqs, len(seqs)).tolist()
        for _ in range(MAXLEN - len(encoded)):
            encoded.append([0.0] * len(all_symbol_set))
        input_item.append(encoded)
    if input_item:
        inputs.append(input_item)
        outputs.append(delta_g)
    
    # mut
    input_item = []
    for key in ["mut_name_0", "mut_name_1"]:
        seqs = id_seq_dict[row[key]]
        if len(seqs) > MAXLEN:
            break
        delta_g = row["delta_g_mut"]
        encoded = ctable.encode(seqs, len(seqs)).tolist()
        for _ in range(MAXLEN - len(encoded)):
            encoded.append([0.0] * len(all_symbol_set))
        input_item.append(encoded)
    
    if input_item:
        inputs.append(input_item)
        outputs.append(delta_g)

# %%
inputs = np.array(inputs).reshape(len(inputs), MAXLEN, len(all_symbol_set), 2)
outputs = np.array(outputs)
len(inputs) == len(outputs)
# Out:
# True

# %%
print(inputs.shape, outputs.shape)
# Out:
# (8006, 434, 20, 2) (8006,)

# %%
train_size = int(len(inputs) * 0.9)

train_x = inputs[:train_size]
train_y = outputs[:train_size]

test_x = inputs[train_size:]
test_y = outputs[train_size:]

# %%
print(train_x.shape, train_y.shape, test_x.shape, test_y.shape)
# Out:
# (7205, 434, 20, 2) (7205,) (801, 434, 20, 2) (801,)

# %%
input_shape = (MAXLEN, len(all_symbol_set), 2)
learning_rate = 0.001
batch_size = 192
epochs = 50

model = keras.Sequential(
    [
        keras.Input(shape=input_shape),
        layers.Conv2D(32, kernel_size=(3, 3), activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Conv2D(64, kernel_size=(5, 5), activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Flatten(),
        layers.Dropout(0.5),
        layers.Dense(64, activation="relu"),
        layers.Dense(1),
    ]
)
model.compile(optimizer=keras.optimizers.Adam(learning_rate=learning_rate, amsgrad=True, epsilon=1e-6), loss="mse")
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 432, 18, 32)       608
#
#  max_pooling2d (MaxPooling2D  (None, 216, 9, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 212, 5, 64)        51264
#
#  max_pooling2d_1 (MaxPooling  (None, 106, 2, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 13568)             0
#
#  dropout (Dropout)           (None, 13568)             0
#
#  dense (Dense)               (None, 64)                868416
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 920,353
# Trainable params: 920,353
# Non-trainable params: 0
# _________________________________________________________________
# 2021-11-21 22:50:25.742035: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-21 22:50:25.771951: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-21 22:50:25.772115: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-21 22:50:25.772574: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-11-21 22:50:25.772812: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-21 22:50:25.772949: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-21 22:50:25.773066: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-21 22:50:26.161364: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-21 22:50:26.161528: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-21 22:50:26.161653: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-21 22:50:26.161770: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4777 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1060 6GB, pci bus id: 0000:01:00.0, compute capability: 6.1

# %%
model.fit(train_x, train_y, batch_size=batch_size, epochs=epochs, validation_split=0.1)
# Out:
# Epoch 1/50
# 2021-11-21 22:50:27.536980: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8204
# 34/34 [==============================] - 4s 78ms/step - loss: 21.7841 - val_loss: 7.0537
# Epoch 2/50
# 34/34 [==============================] - 2s 57ms/step - loss: 5.6450 - val_loss: 8.1799
# Epoch 3/50
# 34/34 [==============================] - 2s 57ms/step - loss: 4.1687 - val_loss: 6.7018
# Epoch 4/50
# 34/34 [==============================] - 2s 58ms/step - loss: 3.4332 - val_loss: 6.8400
# Epoch 5/50
# 34/34 [==============================] - 2s 58ms/step - loss: 3.0723 - val_loss: 6.4020
# Epoch 6/50
# 34/34 [==============================] - 2s 58ms/step - loss: 2.8332 - val_loss: 6.2490
# Epoch 7/50
# 34/34 [==============================] - 2s 58ms/step - loss: 2.6729 - val_loss: 6.2057
# Epoch 8/50
# 34/34 [==============================] - 2s 57ms/step - loss: 2.6207 - val_loss: 6.6241
# Epoch 9/50
# 34/34 [==============================] - 2s 57ms/step - loss: 2.5592 - val_loss: 6.3429
# Epoch 10/50
# 34/34 [==============================] - 2s 57ms/step - loss: 2.6245 - val_loss: 5.9579
# Epoch 11/50
# 34/34 [==============================] - 2s 57ms/step - loss: 2.6956 - val_loss: 6.1876
# Epoch 12/50
# 34/34 [==============================] - 2s 57ms/step - loss: 2.4900 - val_loss: 6.0522
# Epoch 13/50
# 34/34 [==============================] - 2s 58ms/step - loss: 2.4383 - val_loss: 5.6489
# Epoch 14/50
# 34/34 [==============================] - 2s 57ms/step - loss: 2.5153 - val_loss: 6.1081
# Epoch 15/50
# 34/34 [==============================] - 2s 57ms/step - loss: 2.4955 - val_loss: 5.6045
# Epoch 16/50
# 34/34 [==============================] - 2s 58ms/step - loss: 2.4539 - val_loss: 5.3801
# Epoch 17/50
# 34/34 [==============================] - 2s 57ms/step - loss: 2.4517 - val_loss: 5.4178
# Epoch 18/50
# 34/34 [==============================] - 2s 57ms/step - loss: 2.4819 - val_loss: 5.8154
# Epoch 19/50
# 34/34 [==============================] - 2s 57ms/step - loss: 2.3714 - val_loss: 6.1482
# Epoch 20/50
# 34/34 [==============================] - 2s 57ms/step - loss: 2.4451 - val_loss: 5.1894
# Epoch 21/50
# 34/34 [==============================] - 2s 57ms/step - loss: 2.3638 - val_loss: 5.4724
# Epoch 22/50
# 34/34 [==============================] - 2s 57ms/step - loss: 2.3408 - val_loss: 5.1800
# Epoch 23/50
# 34/34 [==============================] - 2s 57ms/step - loss: 2.4163 - val_loss: 4.9556
# Epoch 24/50
# 34/34 [==============================] - 2s 57ms/step - loss: 2.3026 - val_loss: 5.3066
# Epoch 25/50
# 34/34 [==============================] - 2s 57ms/step - loss: 2.3523 - val_loss: 5.1942
# Epoch 26/50
# 34/34 [==============================] - 2s 58ms/step - loss: 2.3347 - val_loss: 4.9630
# Epoch 27/50
# 34/34 [==============================] - 2s 57ms/step - loss: 2.3477 - val_loss: 4.9723
# Epoch 28/50
# 34/34 [==============================] - 2s 57ms/step - loss: 2.3031 - val_loss: 4.9230
# Epoch 29/50
# 34/34 [==============================] - 2s 57ms/step - loss: 2.2725 - val_loss: 4.8175
# Epoch 30/50
# 34/34 [==============================] - 2s 57ms/step - loss: 2.2901 - val_loss: 4.8984
# Epoch 31/50
# 34/34 [==============================] - 2s 57ms/step - loss: 2.3033 - val_loss: 5.3607
# Epoch 32/50
# 34/34 [==============================] - 2s 57ms/step - loss: 2.3279 - val_loss: 5.1192
# Epoch 33/50
# 34/34 [==============================] - 2s 57ms/step - loss: 2.2328 - val_loss: 4.8642
# Epoch 34/50
# 34/34 [==============================] - 2s 57ms/step - loss: 2.2591 - val_loss: 4.9012
# Epoch 35/50
# 34/34 [==============================] - 2s 57ms/step - loss: 2.2220 - val_loss: 5.0439
# Epoch 36/50
# 34/34 [==============================] - 2s 57ms/step - loss: 2.2411 - val_loss: 4.9602
# Epoch 37/50
# 34/34 [==============================] - 2s 57ms/step - loss: 2.2294 - val_loss: 5.0230
# Epoch 38/50
# 34/34 [==============================] - 2s 57ms/step - loss: 2.3595 - val_loss: 5.5273
# Epoch 39/50
# 34/34 [==============================] - 2s 57ms/step - loss: 2.3397 - val_loss: 4.7089
# Epoch 40/50
# 34/34 [==============================] - 2s 57ms/step - loss: 2.3110 - val_loss: 4.7583
# Epoch 41/50
# 34/34 [==============================] - 2s 57ms/step - loss: 2.1887 - val_loss: 4.8742
# Epoch 42/50
# 34/34 [==============================] - 2s 57ms/step - loss: 2.1479 - val_loss: 4.8920
# Epoch 43/50
# 34/34 [==============================] - 2s 57ms/step - loss: 2.1921 - val_loss: 4.9187
# Epoch 44/50
# 34/34 [==============================] - 2s 57ms/step - loss: 2.1735 - val_loss: 5.0180
# Epoch 45/50
# 34/34 [==============================] - 2s 57ms/step - loss: 2.1085 - val_loss: 4.8206
# Epoch 46/50
# 34/34 [==============================] - 2s 57ms/step - loss: 2.1070 - val_loss: 4.8514
# Epoch 47/50
# 34/34 [==============================] - 2s 57ms/step - loss: 2.1482 - val_loss: 4.9391
# Epoch 48/50
# 34/34 [==============================] - 2s 57ms/step - loss: 2.1679 - val_loss: 4.9512
# Epoch 49/50
# 34/34 [==============================] - 2s 57ms/step - loss: 2.1504 - val_loss: 4.9787
# Epoch 50/50
# 34/34 [==============================] - 2s 57ms/step - loss: 2.0836 - val_loss: 4.8523

# %%
score = model.evaluate(test_x, test_y, verbose=0)
score
# Out:
# 4.877392292022705

# %%
test_y[0]
# Out:
# -8.633059487634572

# %%
model.predict(test_x)
# Out:
# array([[-11.047307 ],
#        [-11.14163  ],
#        [-11.115495 ],
#        [-11.14163  ],
#        [-11.173584 ],
#        [-11.14163  ],
#        [-11.171309 ],
#        [-11.14163  ],
#        [-11.117297 ],
#        [-11.14163  ],
#        [-11.153526 ],
#        [-11.14163  ],
#        [-11.125926 ],
#        [-11.14163  ],
#        [-11.131533 ],
#        [-11.14163  ],
#        [-11.215392 ],
#        [-11.14163  ],
#        [-11.129463 ],
#        [-11.14163  ],
#        [-11.095613 ],
#        [-11.14163  ],
#        [-11.147159 ],
#        [-11.14163  ],
#        [-11.049715 ],
#        [-11.14163  ],
#        [-11.174175 ],
#        [-11.14163  ],
#        [-11.070275 ],
#        [-11.14163  ],
#        [-11.047307 ],
#        [-11.14163  ],
#        [-11.149408 ],
#        [-11.14163  ],
#        [-11.127148 ],
#        [-11.14163  ],
#        [-11.153315 ],
#        [-11.14163  ],
#        [-11.139096 ],
#        [ -8.604914 ],
#        [ -8.583326 ],
#        [ -8.604914 ],
#        [ -8.648729 ],
#        [ -9.804913 ],
#        [ -9.802313 ],
#        [ -9.804913 ],
#        [ -9.805265 ],
#        [-10.551185 ],
#        [-10.554551 ],
#        [-11.00826  ],
#        [-11.028784 ],
#        [-11.00826  ],
#        [-11.028784 ],
#        [-11.00826  ],
#        [-11.028784 ],
#        [-11.00826  ],
#        [-10.979644 ],
#        [-11.00826  ],
#        [-10.979644 ],
#        [-11.00826  ],
#        [-10.979644 ],
#        [-11.00826  ],
#        [-11.017405 ],
#        [-11.00826  ],
#        [-11.017405 ],
#        [-11.00826  ],
#        [-11.017405 ],
#        [-11.00826  ],
#        [-10.999568 ],
#        [-11.00826  ],
#        [-10.999568 ],
#        [-11.00826  ],
#        [-10.999568 ],
#        [-11.00826  ],
#        [-10.962568 ],
#        [-11.00826  ],
#        [-10.962568 ],
#        [-11.00826  ],
#        [-10.962568 ],
#        [-11.00826  ],
#        [-11.016424 ],
#        [-11.00826  ],
#        [-11.016424 ],
#        [-11.00826  ],
#        [-11.016424 ],
#        [-11.00826  ],
#        [-10.985289 ],
#        [-11.00826  ],
#        [-10.985289 ],
#        [-11.00826  ],
#        [-10.985289 ],
#        [-11.00826  ],
#        [-10.945794 ],
#        [-11.00826  ],
#        [-10.945794 ],
#        [-11.00826  ],
#        [-10.945794 ],
#        [-11.00826  ],
#        [-10.9827   ],
#        [-11.00826  ],
#        [-10.9827   ],
#        [-11.00826  ],
#        [-10.9827   ],
#        [-11.00826  ],
#        [-10.935035 ],
#        [-11.00826  ],
#        [-10.935035 ],
#        [-11.00826  ],
#        [-10.935035 ],
#        [-11.00826  ],
#        [-10.975305 ],
#        [-11.00826  ],
#        [-11.013361 ],
#        [-11.00826  ],
#        [-11.013361 ],
#        [-11.00826  ],
#        [-11.021379 ],
#        [-11.00826  ],
#        [-11.021379 ],
#        [-11.00826  ],
#        [-11.031674 ],
#        [-11.00826  ],
#        [-11.031674 ],
#        [-11.00826  ],
#        [-11.031674 ],
#        [-11.00826  ],
#        [-10.989695 ],
#        [-11.00826  ],
#        [-11.004598 ],
#        [-11.00826  ],
#        [-10.996915 ],
#        [-11.00826  ],
#        [-11.076706 ],
#        [-11.00826  ],
#        [-11.031669 ],
#        [-11.00826  ],
#        [-11.031669 ],
#        [-11.00826  ],
#        [-10.95388  ],
#        [ -7.826342 ],
#        [ -7.8182425],
#        [ -7.826342 ],
#        [ -7.842885 ],
#        [ -7.826342 ],
#        [ -7.8545423],
#        [ -7.826342 ],
#        [ -7.864618 ],
#        [ -7.826342 ],
#        [ -7.857713 ],
#        [ -7.826342 ],
#        [ -7.8361917],
#        [ -7.826342 ],
#        [ -7.858858 ],
#        [ -7.826342 ],
#        [ -7.8011675],
#        [ -7.826342 ],
#        [ -7.8828697],
#        [ -7.826342 ],
#        [ -7.8027477],
#        [ -7.826342 ],
#        [ -7.924094 ],
#        [ -7.826342 ],
#        [ -7.877222 ],
#        [ -7.826342 ],
#        [ -7.8983965],
#        [ -7.826342 ],
#        [ -7.7962976],
#        [ -7.826342 ],
#        [ -7.8537498],
#        [ -7.826342 ],
#        [ -7.812376 ],
#        [ -7.826342 ],
#        [ -7.865795 ],
#        [ -7.826342 ],
#        [ -7.8182425],
#        [ -7.826342 ],
#        [ -7.842885 ],
#        [ -7.826342 ],
#        [ -7.8545423],
#        [ -7.826342 ],
#        [ -7.864618 ],
#        [ -7.826342 ],
#        [ -7.857713 ],
#        [ -7.826342 ],
#        [ -7.8642144],
#        [ -7.826342 ],
#        [ -7.8361917],
#        [ -7.826342 ],
#        [ -7.858858 ],
#        [ -7.826342 ],
#        [ -7.8011675],
#        [ -7.826342 ],
#        [ -7.8828697],
#        [ -7.826342 ],
#        [ -7.8027477],
#        [ -7.826342 ],
#        [ -7.924094 ],
#        [ -7.826342 ],
#        [ -7.877222 ],
#        [ -7.826342 ],
#        [ -7.9524965],
#        [ -7.826342 ],
#        [ -7.808842 ],
#        [ -7.826342 ],
#        [ -7.852937 ],
#        [ -7.826342 ],
#        [ -7.8537498],
#        [ -7.826342 ],
#        [ -7.812376 ],
#        [ -7.826342 ],
#        [ -7.8644834],
#        [ -7.826342 ],
#        [ -7.865795 ],
#        [ -7.826342 ],
#        [ -7.836482 ],
#        [ -7.826342 ],
#        [ -7.828257 ],
#        [ -8.876589 ],
#        [ -8.848657 ],
#        [ -8.876589 ],
#        [ -8.869418 ],
#        [ -8.876589 ],
#        [ -8.810235 ],
#        [ -8.876589 ],
#        [ -8.849878 ],
#        [ -8.876589 ],
#        [ -8.95118  ],
#        [ -8.876589 ],
#        [ -8.875393 ],
#        [ -8.876589 ],
#        [ -8.8549185],
#        [ -8.876589 ],
#        [ -8.872094 ],
#        [ -8.876589 ],
#        [ -8.829546 ],
#        [ -8.876589 ],
#        [ -8.86895  ],
#        [ -8.876589 ],
#        [ -8.847302 ],
#        [ -8.876589 ],
#        [ -8.869789 ],
#        [ -8.876589 ],
#        [ -8.866843 ],
#        [ -8.876589 ],
#        [ -8.888649 ],
#        [ -8.876589 ],
#        [ -8.86887  ],
#        [ -8.876589 ],
#        [ -8.819852 ],
#        [ -8.876589 ],
#        [ -8.861766 ],
#        [ -8.876589 ],
#        [ -8.900435 ],
#        [ -8.333979 ],
#        [ -8.306096 ],
#        [ -8.333979 ],
#        [ -8.326418 ],
#        [ -8.333979 ],
#        [ -8.285919 ],
#        [ -8.333979 ],
#        [ -8.321337 ],
#        [ -8.333979 ],
#        [ -8.357328 ],
#        [ -8.333979 ],
#        [ -8.169961 ],
#        [ -8.333979 ],
#        [ -8.34024  ],
#        [ -8.333979 ],
#        [ -8.383335 ],
#        [ -8.333979 ],
#        [ -8.261098 ],
#        [ -8.333979 ],
#        [ -8.332052 ],
#        [ -8.333979 ],
#        [ -8.296578 ],
#        [ -9.572724 ],
#        [ -9.429853 ],
#        [ -9.572724 ],
#        [ -9.513046 ],
#        [ -9.572724 ],
#        [ -9.741106 ],
#        [ -9.572724 ],
#        [ -9.443393 ],
#        [ -9.572724 ],
#        [ -9.675443 ],
#        [ -9.572724 ],
#        [ -9.480357 ],
#        [ -9.572724 ],
#        [ -9.482055 ],
#        [ -9.572724 ],
#        [ -9.565927 ],
#        [ -9.572724 ],
#        [ -9.584786 ],
#        [ -9.572724 ],
#        [ -9.565006 ],
#        [ -9.572724 ],
#        [ -9.616464 ],
#        [ -9.572724 ],
#        [ -9.668124 ],
#        [ -9.572724 ],
#        [ -9.515989 ],
#        [ -9.572724 ],
#        [ -9.543578 ],
#        [ -9.572724 ],
#        [ -9.544145 ],
#        [ -9.572724 ],
#        [ -9.555495 ],
#        [ -9.572724 ],
#        [ -9.577686 ],
#        [ -9.572724 ],
#        [ -9.615075 ],
#        [ -9.572724 ],
#        [ -9.557614 ],
#        [ -8.876589 ],
#        [ -9.070002 ],
#        [ -8.876589 ],
#        [ -8.893415 ],
#        [ -8.876589 ],
#        [ -8.70558  ],
#        [ -8.876589 ],
#        [ -8.880099 ],
#        [ -8.606495 ],
#        [ -8.576913 ],
#        [ -8.606495 ],
#        [ -8.396714 ],
#        [ -8.876589 ],
#        [ -8.915901 ],
#        [ -8.606495 ],
#        [ -8.645808 ],
#        [ -8.333979 ],
#        [ -8.380459 ],
#        [ -9.270956 ],
#        [ -9.324199 ],
#        [ -9.270956 ],
#        [ -9.2158575],
#        [ -9.270956 ],
#        [ -8.792741 ],
#        [ -9.270956 ],
#        [ -8.758562 ],
#        [ -9.270956 ],
#        [ -9.186776 ],
#        [ -9.270956 ],
#        [ -9.147213 ],
#        [ -9.270956 ],
#        [ -9.201211 ],
#        [ -9.270956 ],
#        [ -8.816374 ],
#        [ -9.270956 ],
#        [ -9.248198 ],
#        [ -9.270956 ],
#        [ -9.205875 ],
#        [ -9.270956 ],
#        [ -8.761924 ],
#        [ -9.270956 ],
#        [ -9.177743 ],
#        [ -9.270956 ],
#        [ -9.403679 ],
#        [ -9.270956 ],
#        [ -9.298028 ],
#        [ -8.876589 ],
#        [ -8.8472   ],
#        [ -8.876589 ],
#        [ -8.869418 ],
#        [ -8.876589 ],
#        [ -8.91267  ],
#        [ -8.876589 ],
#        [ -8.875393 ],
#        [ -8.876589 ],
#        [ -8.921845 ],
#        [ -8.876589 ],
#        [ -8.938044 ],
#        [ -8.876589 ],
#        [ -8.95118  ],
#        [ -8.876589 ],
#        [ -8.849878 ],
#        [ -8.876589 ],
#        [ -8.848657 ],
#        [ -8.876589 ],
#        [ -8.810235 ],
#        [ -8.876589 ],
#        [ -8.8549185],
#        [ -8.876589 ],
#        [ -8.845504 ],
#        [ -8.876589 ],
#        [ -8.9365015],
#        [ -8.876589 ],
#        [ -8.847302 ],
#        [ -8.876589 ],
#        [ -8.869789 ],
#        [ -8.876589 ],
#        [ -8.861766 ],
#        [ -8.876589 ],
#        [ -8.848657 ],
#        [ -8.876589 ],
#        [ -8.869418 ],
#        [ -8.876589 ],
#        [ -8.849878 ],
#        [ -8.876589 ],
#        [ -8.875393 ],
#        [ -8.876589 ],
#        [ -8.8549185],
#        [ -8.876589 ],
#        [ -8.872094 ],
#        [ -8.876589 ],
#        [ -8.958736 ],
#        [ -8.876589 ],
#        [ -8.915901 ],
#        [ -8.156483 ],
#        [ -8.15267  ],
#        [ -8.156483 ],
#        [ -8.183948 ],
#        [ -8.37064  ],
#        [ -8.354891 ],
#        [ -8.37064  ],
#        [ -8.387565 ],
#        [ -8.37064  ],
#        [ -8.329489 ],
#        [ -8.37064  ],
#        [ -8.319715 ],
#        [ -8.37064  ],
#        [ -8.191445 ],
#        [ -8.37064  ],
#        [ -8.34469  ],
#        [ -8.37064  ],
#        [ -8.0559635],
#        [ -8.37064  ],
#        [ -8.300527 ],
#        [ -8.37064  ],
#        [ -7.817344 ],
#        [ -8.37064  ],
#        [ -7.988879 ],
#        [ -8.139468 ],
#        [ -8.4541445],
#        [ -8.466455 ],
#        [ -8.44904  ],
#        [ -8.466455 ],
#        [ -8.478165 ],
#        [ -8.466455 ],
#        [ -8.425304 ],
#        [ -8.466455 ],
#        [ -8.41553  ],
#        [ -8.466455 ],
#        [ -8.35221  ],
#        [ -8.466455 ],
#        [ -8.4942665],
#        [ -8.466455 ],
#        [ -8.16898  ],
#        [ -8.466455 ],
#        [ -8.38821  ],
#        [ -8.466455 ],
#        [ -7.832971 ],
#        [ -8.466455 ],
#        [ -8.034664 ],
#        [ -8.466455 ],
#        [ -8.019726 ],
#        [-10.887553 ],
#        [-10.837381 ],
#        [-10.887553 ],
#        [-10.959545 ],
#        [-10.887553 ],
#        [-10.94842  ],
#        [-10.887553 ],
#        [-10.882047 ],
#        [-10.887553 ],
#        [-10.9123335],
#        [-10.887553 ],
#        [-10.939704 ],
#        [-10.887553 ],
#        [-10.882116 ],
#        [-10.887553 ],
#        [-10.822238 ],
#        [-10.887553 ],
#        [-10.918869 ],
#        [-10.887553 ],
#        [-10.819678 ],
#        [-10.887553 ],
#        [-10.878012 ],
#        [-10.887553 ],
#        [-10.827199 ],
#        [-10.887553 ],
#        [-10.859007 ],
#        [-10.887553 ],
#        [-10.896426 ],
#        [-10.887553 ],
#        [-10.851695 ],
#        [-10.887553 ],
#        [-10.822466 ],
#        [-10.887553 ],
#        [-10.803108 ],
#        [-10.887553 ],
#        [-10.937696 ],
#        [-10.887553 ],
#        [-10.920512 ],
#        [-10.887553 ],
#        [-10.908471 ],
#        [-10.887553 ],
#        [-10.890324 ],
#        [-10.887553 ],
#        [-10.901766 ],
#        [-10.887553 ],
#        [-10.897533 ],
#        [-10.887553 ],
#        [-10.886086 ],
#        [-10.887553 ],
#        [-10.869655 ],
#        [-10.887553 ],
#        [-10.8683195],
#        [-10.887553 ],
#        [-10.855488 ],
#        [-10.887553 ],
#        [-10.887398 ],
#        [-10.887553 ],
#        [-10.889178 ],
#        [ -9.425281 ],
#        [ -9.354757 ],
#        [ -9.425281 ],
#        [ -9.37942  ],
#        [ -9.425281 ],
#        [ -9.507375 ],
#        [ -9.425281 ],
#        [ -9.347858 ],
#        [ -9.425281 ],
#        [ -9.470949 ],
#        [ -9.425281 ],
#        [ -9.381505 ],
#        [ -9.425281 ],
#        [ -9.376472 ],
#        [ -9.425281 ],
#        [ -9.470729 ],
#        [ -9.425281 ],
#        [ -9.334002 ],
#        [ -9.425281 ],
#        [ -9.40446  ],
#        [ -9.425281 ],
#        [ -9.4125395],
#        [ -9.425281 ],
#        [ -9.420916 ],
#        [ -9.425281 ],
#        [ -9.416271 ],
#        [ -9.425281 ],
#        [ -9.405392 ],
#        [ -9.425281 ],
#        [ -9.434973 ],
#        [ -9.425281 ],
#        [ -9.464608 ],
#        [ -9.425281 ],
#        [ -9.412361 ],
#        [ -9.425281 ],
#        [ -9.420881 ],
#        [ -9.425281 ],
#        [ -9.416123 ],
#        [ -9.425281 ],
#        [ -9.395875 ],
#        [ -9.425281 ],
#        [ -9.428595 ],
#        [ -9.425281 ],
#        [ -9.4739485],
#        [ -9.425281 ],
#        [ -9.392417 ],
#        [ -9.425281 ],
#        [ -9.432997 ],
#        [ -9.425281 ],
#        [ -9.425029 ],
#        [-11.957639 ],
#        [-11.985501 ],
#        [-11.957639 ],
#        [-11.929476 ],
#        [-11.957639 ],
#        [-12.038878 ],
#        [-11.957639 ],
#        [-12.01784  ],
#        [-11.957639 ],
#        [-11.920614 ],
#        [-11.957639 ],
#        [-12.133736 ],
#        [-11.957639 ],
#        [-11.907958 ],
#        [-11.957639 ],
#        [-11.923409 ],
#        [-11.957639 ],
#        [-11.932799 ],
#        [-11.957639 ],
#        [-11.967613 ],
#        [-11.957639 ],
#        [-11.966401 ],
#        [-11.957639 ],
#        [-11.924951 ],
#        [-11.957639 ],
#        [-12.005747 ],
#        [-11.957639 ],
#        [-11.986709 ],
#        [-11.957639 ],
#        [-11.960535 ],
#        [-11.957639 ],
#        [-11.960148 ],
#        [-11.957639 ],
#        [-11.95824  ],
#        [-11.957639 ],
#        [-11.968539 ],
#        [-11.957639 ],
#        [-11.942851 ],
#        [-11.957639 ],
#        [-12.026328 ],
#        [-11.957639 ],
#        [-11.950299 ],
#        [-11.957639 ],
#        [-11.946775 ],
#        [-11.957639 ],
#        [-11.964191 ],
#        [-11.957639 ],
#        [-12.051063 ],
#        [-11.957639 ],
#        [-11.987806 ],
#        [-11.954119 ],
#        [-12.038665 ],
#        [-11.954119 ],
#        [-11.966564 ],
#        [-11.954119 ],
#        [-11.909118 ],
#        [-11.954119 ],
#        [-12.035034 ],
#        [-11.954119 ],
#        [-11.872462 ],
#        [-11.954119 ],
#        [-12.114772 ],
#        [-11.954119 ],
#        [-11.875851 ],
#        [-11.954119 ],
#        [-11.927989 ],
#        [-11.954119 ],
#        [-11.94773  ],
#        [-11.954119 ],
#        [-11.962957 ],
#        [-11.954119 ],
#        [-11.955324 ],
#        [-11.954119 ],
#        [-11.918504 ],
#        [-11.954119 ],
#        [-11.988814 ],
#        [-11.954119 ],
#        [-12.04127  ],
#        [-11.954119 ],
#        [-11.888802 ],
#        [-11.954119 ],
#        [-11.942413 ],
#        [-11.954119 ],
#        [-11.946895 ],
#        [-11.954119 ],
#        [-11.959606 ],
#        [-11.954119 ],
#        [-11.9559355],
#        [-11.954119 ],
#        [-11.986486 ],
#        [-11.954119 ],
#        [-11.943081 ],
#        [-11.954119 ],
#        [-11.942197 ],
#        [-11.954119 ],
#        [-11.941412 ],
#        [-11.954119 ],
#        [-12.010426 ],
#        [-11.954119 ],
#        [-11.989923 ],
#        [ -8.307375 ],
#        [ -8.30887  ],
#        [ -8.307375 ],
#        [ -8.292081 ],
#        [ -8.307375 ],
#        [ -8.287934 ],
#        [ -8.307375 ],
#        [ -8.198585 ],
#        [ -8.307375 ],
#        [ -8.156566 ],
#        [ -8.68463  ],
#        [ -8.660097 ],
#        [ -8.68463  ],
#        [ -8.642723 ],
#        [ -8.68463  ],
#        [ -8.795602 ],
#        [ -8.68463  ],
#        [ -8.566467 ],
#        [ -8.68463  ],
#        [ -8.732144 ],
#        [ -8.68463  ],
#        [ -8.683986 ],
#        [ -8.68463  ],
#        [ -8.725865 ],
#        [ -8.68463  ],
#        [ -8.679571 ],
#        [ -8.68463  ],
#        [ -8.686464 ],
#        [ -8.68463  ],
#        [ -8.697429 ],
#        [ -8.68463  ],
#        [ -8.663414 ],
#        [ -8.68463  ],
#        [ -8.718185 ],
#        [ -8.68463  ],
#        [ -8.711828 ],
#        [ -8.68463  ],
#        [ -8.622987 ],
#        [ -9.702466 ],
#        [ -9.660318 ],
#        [ -8.581747 ],
#        [ -8.577356 ],
#        [ -7.6842976],
#        [ -7.6703787],
#        [ -7.6842976],
#        [ -7.699774 ],
#        [ -7.6842976],
#        [ -7.5095596],
#        [ -7.6842976],
#        [ -7.59216  ],
#        [ -7.6842976],
#        [ -7.440358 ],
#        [ -7.6842976],
#        [ -7.607359 ],
#        [ -7.6842976],
#        [ -7.580566 ],
#        [ -7.6842976],
#        [ -7.6394625],
#        [ -7.6842976],
#        [ -7.7954097],
#        [ -7.6842976],
#        [ -7.7374263],
#        [ -7.6842976],
#        [ -7.528997 ],
#        [ -9.075082 ],
#        [ -9.062504 ],
#        [ -9.075082 ],
#        [ -9.062504 ],
#        [ -9.075082 ],
#        [ -9.067984 ],
#        [ -9.075082 ],
#        [ -9.06407  ],
#        [ -9.104073 ],
#        [ -9.1166525],
#        [ -9.104073 ],
#        [ -9.1166525],
#        [ -9.104073 ],
#        [ -9.109552 ],
#        [ -9.104073 ],
#        [ -9.105639 ],
#        [ -9.075082 ],
#        [ -9.035582 ],
#        [ -9.075082 ],
#        [ -9.062504 ],
#        [ -9.104073 ],
#        [ -9.1166525],
#        [ -9.174205 ],
#        [ -9.069326 ],
#        [ -9.174205 ],
#        [ -9.13092  ],
#        [ -9.174205 ],
#        [ -9.089858 ],
#        [ -9.174205 ],
#        [ -9.242893 ],
#        [ -9.174205 ],
#        [ -9.157204 ],
#        [ -9.174205 ],
#        [ -9.207922 ],
#        [ -9.174205 ],
#        [ -9.162028 ],
#        [ -9.174205 ],
#        [ -9.160616 ],
#        [ -9.4270115],
#        [ -9.374711 ],
#        [ -9.4270115],
#        [ -9.391979 ],
#        [ -9.4270115],
#        [ -9.393989 ],
#        [ -9.4270115],
#        [ -9.367987 ],
#        [ -9.4270115],
#        [ -9.427423 ],
#        [ -9.4270115],
#        [ -9.42036  ],
#        [ -9.460136 ],
#        [ -9.477713 ],
#        [ -9.460136 ],
#        [ -9.50331  ],
#        [ -9.460136 ],
#        [ -9.50414  ],
#        [ -9.460136 ],
#        [ -9.425828 ],
#        [ -9.460136 ],
#        [ -9.498466 ],
#        [-10.766718 ],
#        [-10.7750025],
#        [-10.766718 ],
#        [-10.7750025],
#        [-10.766718 ],
#        [-10.7750025],
#        [ -9.723265 ],
#        [ -9.718749 ],
#        [ -9.723265 ],
#        [ -9.726377 ],
#        [ -9.723265 ],
#        [ -9.713412 ],
#        [ -9.723265 ],
#        [ -9.602889 ]], dtype=float32)
